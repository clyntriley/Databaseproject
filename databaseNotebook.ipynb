-- %% [markdown]
-- Sql

-- %%
SELECT TOP (1000) [_0_12_Patch]
      ,[Weight_KG]
      ,[Rub_price]
      ,[Damage]
      ,[Accuracy]
      ,[Recoil]
      ,[Penetration_Value]
      ,[Projectile_Count]
      ,[Projectile_Speed_m_s]
      ,[Penetration_Chance]
      ,[Ricochet_Chance]
      ,[Fragmentation_Chance]
      ,[Armor_Damage]
      ,[column14]
      ,[column15]
  FROM [test_db].[dbo].[Escape from Tarkov  ammo table - 0.12 Patch]
-- Out:
-- (126 rows affected)
-- Total execution time: 00:00:00.072
-- ...

-- %%
SELECT TOP (1000) 
[Damage]
,[Penetration_Value]
,[Armor_Damage]
FROM [test_db].[dbo].[Escape from Tarkov  ammo table - 0.12 Patch]
WHERE _0_12_Patch = '7.62x51 mm M61'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>Damage</th><th>Penetration_Value</th><th>Armor_Damage</th></tr><tr><td>70</td><td>68</td><td>83</td></tr></table>

-- %%
SELECT TOP (1000)
*
FROM [test_db].[dbo].[Escape from Tarkov  ammo table - 0.12 Patch]
WHERE Penetration_Value BETWEEN 40 And 60
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.008
-- ...
